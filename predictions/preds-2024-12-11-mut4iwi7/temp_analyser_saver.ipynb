# %%
import pandas as pd

# %%
df = pd.read_csv('predictions.csv')
df
# Out:
#         ID  MatchID  PeriodID  \
# 0      6_0        6         0
# 1      6_1        6         1
# 2     6_10        6        10
# 3    6_100        6       100
# 4    6_101        6       101
# ..     ...      ...       ...
# 511  16_95       16        95
# 512  16_96       16        96
# 513  16_97       16        97
# 514  16_98       16        98
# 515  16_99       16        99
#
#                                                  Tweet  EventType  Probability
# 0    ['I Finally get to see Germany play\n#GER   🇩🇪...          1     0.548331
# 1    ['"In a few minutes #BigGame of #GER x #GHA......          1     0.877501
# 2    ['Ghana invented the gravity bong #WorldCup #f...          1     0.973127
# 3    ['THIS GAME. #GhanavsGermany #WorldCup', "Let'...          1     0.975921
# 4    ['Klose! You come on the pitch, the ball goes ...          1     0.974776
# ..                                                 ...        ...          ...
# 511  ["Not one mullet in the German team. They won'...          0     0.410303
# 512  ["#worldcup #live #srb  69' : Changement serbe...          1     0.873146
# 513  ["#ger miss penalty. Their inexperienced squad...          1     0.887322
# 514  ['Der Schiri nervt. #worldcup #ger #srb', "#wo...          1     0.730534
# 515  ['#worldcup  ä¸–ç•Œæ\x9d¯è‡³ä»Šï¼Œå¼ºé˜Ÿä¸\x8d...          1     0.956002
#
# [516 rows x 6 columns]

# %%
df = df.sort_values(by=['MatchID', 'PeriodID']).reset_index(drop=True)
df
# Out:
#          ID  MatchID  PeriodID  \
# 0       6_0        6         0
# 1       6_1        6         1
# 2       6_2        6         2
# 3       6_3        6         3
# 4       6_4        6         4
# ..      ...      ...       ...
# 511  16_125       16       125
# 512  16_126       16       126
# 513  16_127       16       127
# 514  16_128       16       128
# 515  16_129       16       129
#
#                                                  Tweet  EventType  Probability
# 0    ['I Finally get to see Germany play\n#GER   🇩🇪...          1     0.548331
# 1    ['"In a few minutes #BigGame of #GER x #GHA......          1     0.877501
# 2    ['I’m supporting Germany in the FIFA Global St...          1     0.688010
# 3    ['Future World Cup champions are about to play...          1     0.826983
# 4    ['Thing is.. Ozil looks like one of my aquariu...          1     0.874263
# ..                                                 ...        ...          ...
# 511  ['Someone here just described Group D as "lite...          1     0.948901
# 512  ['Stat comparison between Serbia & Germany s i...          1     0.931510
# 513  ["OMFG #GER just lost??? I'm glad I'm at work ...          1     0.909796
# 514  ['ç›´å‰\x8däºˆæƒ³0-0ã\x81¯å¤–ã‚Œã€‚ã‚»ãƒ«ãƒ“ã‚...          1     0.942820
# 515  [':)))) Nije mala, nije mala... #WorldCup #SRB...          1     0.858275
#
# [516 rows x 6 columns]

# %%
# filter for match 6 and show all rows oin notebook
pd.set_option('display.max_rows', 500)
df_new = df[df['MatchID'] == 6].reset_index(drop=True)
df_new.head(200)

# %%
df2 = df[['ID', 'EventType']]
df2
# Out:
#          ID  EventType
# 0       6_0          1
# 1       6_1          1
# 2       6_2          1
# 3       6_3          1
# 4       6_4          1
# ..      ...        ...
# 511  16_125          1
# 512  16_126          1
# 513  16_127          1
# 514  16_128          1
# 515  16_129          1
#
# [516 rows x 2 columns]

# %%
df2.columns = ['ID', 'EventType']
df2

# %%
df2.to_csv('predictions-2024-12-11-g6m9feze.csv', index=False)

# %%
# for comparisons
df3 = pd.read_csv('predictions-2024-12-02-zi4v2v87_old.csv')
df3.equals(df2)
